# %%
import pandas as pd
from scipy.stats import skew
from scipy import stats
from sklearn import preprocessing
from sklearn import decomposition

# %%
glass = pd.read_csv("../data/glass.data")

# %%
glass
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %%
# fitlter only the Case for training data
segdata = segdata[segdata.Case == "Train"]

# %%
cellId = segdata.Cell
class_value = segdata.Class
case = segdata.Case

# %%
segdata = segdata.drop(['Cell', 'Class', 'Case'], axis=1)

# %%
statusColmns = [c for c in segdata.columns if "Status" in c]

# %%
segdata = segdata.drop(statusColmns, axis=1)

# %%
segdata
# Out:
#       MorphologyV2Cell.AngleCh1  MorphologyV2Cell.AreaCh1  \
# 1                    133.752037                       819
# 2                    106.646387                       431
# 3                     69.150325                       298
# 11                   109.416426                       256
# 14                   104.278654                       258
# ...                         ...                       ...
# 2011                 174.682654                       431
# 2012                  50.505043                      1079
# 2013                  87.784450                       187
# 2014                  85.481047                       302
# 2018                 150.820416                       441
#
#       MorphologyV2Cell.AvgIntenCh1  MorphologyV2Cell.AvgIntenCh2  \
# 1                        31.923274                    205.878517
# 2                        28.038835                    115.315534
# 3                        19.456140                    101.294737
# ...

# %%
# transformations

# %%
skew(segdata["MorphologyV2Cell.AngleCh1"])
# Out:
# -0.024298630435426738

# %%
skew_values = segdata.apply(skew)

# %%
skew_values
# Out:
# MorphologyV2Cell.AngleCh1                   -0.024299
# MorphologyV2Cell.AreaCh1                     3.530354
# MorphologyV2Cell.AvgIntenCh1                 2.963590
# MorphologyV2Cell.AvgIntenCh2                 0.849423
# MorphologyV2Cell.AvgIntenCh3                 2.205620
# MorphologyV2Cell.AvgIntenCh4                 1.903300
# MorphologyV2Cell.ConvexHullAreaRatioCh1      2.480268
# MorphologyV2Cell.ConvexHullPerimRatioCh1    -1.306040
# MorphologyV2Cell.DiffIntenDensityCh1         2.764582
# MorphologyV2Cell.DiffIntenDensityCh3         2.088292
# MorphologyV2Cell.DiffIntenDensityCh4         1.902060
# MorphologyV2Cell.EntropyIntenCh1             0.398487
# MorphologyV2Cell.EntropyIntenCh3            -1.004446
# MorphologyV2Cell.EntropyIntenCh4            -0.829137
# MorphologyV2Cell.EqCircDiamCh1               1.958441
# MorphologyV2Cell.EqEllipseLWRCh1             2.698004
# MorphologyV2Cell.EqEllipseOblateVolCh1       5.497484
# ...

# %%
MorphologyV2Cell_AreaCh1_trans, estimated_lambda = stats.boxcox(segdata["MorphologyV2Cell.AreaCh1"])

# %%
estimated_lambda
# Out:
# -0.8558686876415129

# %%
segData_scaled= pd.DataFrame(preprocessing.scale(segdata), index=segdata.index, columns=segdata.columns)

# %%
segData_scaled
# Out:
#       MorphologyV2Cell.AngleCh1  MorphologyV2Cell.AreaCh1  \
# 1                      0.871910                  2.281723
# 2                      0.317462                  0.489144
# 3                     -0.449522                 -0.125323
# 11                     0.374123                 -0.319365
# 14                     0.269030                 -0.310125
# ...                         ...                       ...
# 2011                   1.709148                  0.489144
# 2012                  -0.830913                  3.482935
# 2013                  -0.068360                 -0.638148
# 2014                  -0.115476                 -0.106843
# 2018                   1.221045                  0.535344
#
#       MorphologyV2Cell.AvgIntenCh1  MorphologyV2Cell.AvgIntenCh2  \
# 1                        -0.585557                      0.134415
# 2                        -0.609253                     -0.453999
# 3                        -0.661608                     -0.545096
# ...

# %%
pca = decomposition.PCA(n_components=5)

# %%
segdata_pca = pca.fit(segData_scaled)

# %%
segdata_pca
# Out:
# PCA(copy=True, iterated_power='auto', n_components=5, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
segdata_pca.components_
# Out:
# array([[ 1.21375901e-03,  2.29171873e-01, -1.02708778e-01,
#         -1.54828671e-01, -5.80421579e-02, -1.17343464e-01,
#          2.08230625e-01, -2.14316603e-01, -1.01395191e-01,
#         -4.69278257e-02, -1.11813390e-01, -6.51612518e-02,
#          5.55725124e-02, -6.65746719e-02,  2.26096747e-01,
#          1.09437895e-01,  2.33290590e-01,  1.96721792e-01,
#          2.29168267e-01,  2.20440861e-01, -1.50067256e-03,
#         -1.13577548e-02,  2.72399343e-01, -6.85194308e-02,
#         -5.53103812e-02,  5.41617833e-02,  8.09895237e-02,
#         -2.42310048e-02,  7.44969107e-02, -5.93181506e-02,
#         -5.56128669e-02,  7.27877467e-02,  3.99604621e-02,
#         -1.71772697e-03,  6.11489232e-02,  2.55946178e-01,
#          1.40373192e-02,  7.33402228e-02, -1.24956205e-03,
#          2.71152905e-01, -1.76109779e-01,  9.41234084e-02,
#          2.31575253e-01,  9.32279722e-02, -7.94167010e-03,
#          9.56527498e-02,  1.60701225e-01,  2.32054696e-01,
# ...

# %%
segdata_pca.explained_variance_ratio_
# Out:
# array([0.20912359, 0.170133  , 0.11886892, 0.07715243, 0.04957698])

# %%
segdata_pca.
