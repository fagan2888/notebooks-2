# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("../data/glass.data", names = ["id", "RI", "Na", "Mg", "Al", "Si", "K", "Ca", "Ba", "Fe", "Class"], header = None)

# %%
sns.distplot(data['RI'])

# %%
sns.distplot(data['Na'])

# %%
sns.distplot(data['Mg'])

# %%
sns.distplot(data['Al'])

# %%
sns.distplot(data['Si'])

# %%
sns.distplot(data['K'])

# %%
sns.distplot(data['Ca'])

# %%
sns.distplot(data['Fe'])

# %%
sns.set(style="ticks", color_codes=True)

# %%
data = data.drop(['id'], axis=1)

# %%
g = sns.pairplot(data)

# %%
g = sns.pairplot(data, hue="Class")
